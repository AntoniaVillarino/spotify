# %% [markdown]
# # The data behing Spotify music
#
# - [Spotify](https://www.spotify.com/) is a service with more than **70 million tracks**, and with **345 million active users per month**. With these numbers, Data Analysis is a must! The Spotify databases are enriched with lots of features: *popularity*, *danceability*, *key*... you can see them for yourself in its [API](https://developer.spotify.com/documentation/web-api/).
#
#
# - In my analysis, I'm going to use a [dataset](https://www.kaggle.com/yamaerenay/spotify-dataset-19212020-160k-tracks) collected from this API by a Kaggle user, Yamac Eren Ay. There are two main datasets, one for songs and another one for artists (the other datasets are derived from the first ones, by aggregation techniques)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import re

# %%
import ipywidgets as widgets
from ipywidgets import interact

# %%
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(connected=True)

import cufflinks as cf
cf.go_offline(connected=True)
cf.set_config_file(colorscale='plotly', world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# /home/antonia/anaconda3/lib/python3.8/site-packages/geopandas/_compat.py:84: UserWarning:
#
# The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.0-CAPI-1.16.2). Conversions between both will be slow.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Songs dataset

# %%
df = pd.read_csv('./data/data.csv')
print(df.shape)
df.head()
# Out:
# (174389, 19)
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# 0   -12.628     0                           Keep A Song In Your Soul
# 1    -7.261     0                               I Put A Spell On You
# 2   -12.098     1                                       Golfing Papa
# 3    -7.311     1  True House Music - Xavier Santos & Carlos Gomi...
# 4    -6.036     0                                          Xuniverxe
#
#    popularity release_date  speechiness    tempo  valence  year
# 0          12         1920       0.0936  149.976   0.6340  1920
# 1           7   1920-01-05       0.0534   86.889   0.9500  1920
# 2           4         1920       0.1740   97.600   0.6890  1920
# 3          17   1920-01-01       0.0425  127.997   0.0422  1920
# 4           2   1920-10-01       0.0768  122.076   0.2990  1920

# %% [markdown]
# First, some cleaning:
# - Drop duplicates
# - Check for NaN
# - Tokenize artists

# %%
# check for duplicated items, and drop them
print(f'{df.duplicated().sum()} duplicated tracks')
df = df.drop_duplicates()
df = df.reset_index(drop=True)

# check for NaN values
print(f'{df.isna().sum().sum()} NaN values')

# tokenize artist column
def tokenize_str(text):
    regex_rule = re.compile("['\"\[\]]")
    text = re.sub(regex_rule, "", text)
    return text.split(",")

df['artists'] = df['artists'].apply(tokenize_str)
df.head()
# Out:
# 2159 duplicated tracks
# 0 NaN values
#    acousticness                 artists  danceability  duration_ms  energy  \
# 0      0.991000           [Mamie Smith]         0.598       168333   0.224
# 1      0.643000  [Screamin Jay Hawkins]         0.852       150200   0.517
# 2      0.993000           [Mamie Smith]         0.647       163827   0.186
# 3      0.000173       [Oscar Velazquez]         0.730       422087   0.798
# 4      0.295000                  [Mixe]         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# 0   -12.628     0                           Keep A Song In Your Soul
# 1    -7.261     0                               I Put A Spell On You
# 2   -12.098     1                                       Golfing Papa
# 3    -7.311     1  True House Music - Xavier Santos & Carlos Gomi...
# 4    -6.036     0                                          Xuniverxe
#
#    popularity release_date  speechiness    tempo  valence  year
# 0          12         1920       0.0936  149.976   0.6340  1920
# 1           7   1920-01-05       0.0534   86.889   0.9500  1920
# 2           4         1920       0.1740   97.600   0.6890  1920
# 3          17   1920-01-01       0.0425  127.997   0.0422  1920
# 4           2   1920-10-01       0.0768  122.076   0.2990  1920

# %% [markdown]
# ### Song popularity analysis

# %% [markdown]
# Let's transform the duration into minutes, to see it more clearly

# %%
df['duration_min'] = df['duration_ms']/(1000*60)

# %% [markdown]
# And now let's plot one feature vs the other:

# %%
# I'm going to take a sample, because the graph is so slow...
df_plot = df.sample(frac=0.1)

# %%
@interact
def time_plot(x=list(df_plot.drop(['duration_ms','artists'], axis=1).columns), 
              y=list(df_plot.drop(['duration_ms','artists'], axis=1).columns)):

    df_plot.iplot(kind='scatter', x=x, y=y, mode='markers', size=3,
             xTitle=x.title(), yTitle=y.title(), theme='white', colors='#1DB954',
             title=f'{x.title()} vs {y.title()}')
# Out:
# interactive(children=(Dropdown(description='x', options=('acousticness', 'danceability', 'energy', 'explicit',…

# %% [markdown]
# We can't see much on these graphs!

# %% [markdown]
# ### How has music taste changed over time?

# %% [markdown]
# Let's aggregate by year, now:

# %%
mean_by_year = df.groupby(by='year').mean().reset_index()
mean_by_year
# Out:
#      year  acousticness  danceability    duration_ms    energy  explicit  \
# 0    1920      0.631242      0.515750  238092.997135  0.418700  0.123209
# 1    1921      0.862105      0.432171  257891.762821  0.241136  0.070513
# 2    1922      0.828934      0.575620  140135.140496  0.226173  0.000000
# 3    1923      0.957247      0.577341  177942.362162  0.262406  0.000000
# 4    1924      0.940200      0.549894  191046.707627  0.344347  0.000000
# ..    ...           ...           ...            ...       ...       ...
# 97   2017      0.203493      0.581529  243134.111058  0.687585  0.227404
# 98   2018      0.231001      0.603681  225477.958462  0.659335  0.248462
# 99   2019      0.262731      0.605277  225277.108084  0.627724  0.242519
# 100  2020      0.203989      0.603137  218745.913530  0.673927  0.189034
# 101  2021      0.302344      0.656883  219184.241924  0.622082  0.109117
#
#      instrumentalness       key  liveness   loudness      mode  popularity  \
# 0            0.354219  4.770774  0.216049 -12.654020  0.636103    0.610315
# 1            0.337158  5.108974  0.205219 -16.811660  0.666667    0.391026
# 2            0.254776  4.842975  0.256662 -20.840083  0.661157    0.090909
# 3            0.371733  4.810811  0.227462 -14.129211  0.789189    5.205405
# 4            0.581701  5.648305  0.235219 -14.231343  0.754237    0.661017
# ..                ...       ...       ...        ...       ...         ...
# 97           0.242731  5.318269  0.231528  -8.014637  0.608654   32.733654
# 98           0.226369  5.408846  0.233501  -8.192142  0.583846   28.498462
# 99           0.217415  5.357749  0.218535  -8.536509  0.599375   33.439482
# 100          0.242623  5.353519  0.240397  -8.007122  0.591107   27.051282
# 101          0.267560  5.328069  0.167135  -8.500345  0.586504    9.301508
#
#      speechiness       tempo   valence  duration_min
# 0       0.082984  113.226900  0.498210      3.968217
# 1       0.078952  102.425397  0.378276      4.298196
# 2       0.464368  100.033149  0.571190      2.335586
# 3       0.093949  114.010730  0.625492      2.965706
# 4       0.092089  120.689572  0.663725      3.184112
# ..           ...         ...       ...           ...
# 97      0.097748  121.703343  0.435017      4.052235
# 98      0.122919  123.557107  0.423175      3.757966
# 99      0.107521  122.213681  0.458687      3.754618
# 100     0.099877  123.974626  0.455352      3.645765
# 101     0.104824  122.015177  0.485573      3.653071
#
# [102 rows x 16 columns]

# %%
@interact
def time_plot(y=list(mean_by_year.drop('duration_ms', axis=1).columns)[1:]):

    mean_by_year.iplot(kind='scatter', x='year', y=y, mode='markers', size=5,
             xTitle='year', yTitle=y.title(), theme='white', colors='#1DB954',
             title=f'mean {y.title()} over time')
# Out:
# interactive(children=(Dropdown(description='y', options=('acousticness', 'danceability', 'energy', 'explicit',…

# %% [markdown]
# - Well, we can see that the songs are becoming:
#     - longer,
#     - louder,
#     - with faster tempos
#
#
# - The change in the valence (positiviness of the track) is also interesting: it had more variance in the past, then peaked on the 80's to go down until last year.
#
#
# - The songs also have less variance in the key, and the tendency is going to songs:
#     - between F (*Somebody That I Used to Know (Gotye), Yesterday, Hey Jude*)
#     - and F# keys (*Born this way (Lady Gaga), I wanna dance with somebody (Whitney Houston)*)

# %% [markdown]
# ### Oldest and newest songs

# %%
df.sort_values(by=['year','release_date']).iloc[0]
# Out:
# acousticness                           0.991
# artists                        [Mamie Smith]
# danceability                           0.598
# duration_ms                           168333
# energy                                 0.224
# explicit                                   0
# id                    0cS0A1fUEUd1EW3FcF8AEI
# instrumentalness                    0.000522
# key                                        5
# liveness                               0.379
# loudness                             -12.628
# mode                                       0
# name                Keep A Song In Your Soul
# popularity                                12
# release_date                            1920
# speechiness                           0.0936
# tempo                                149.976
# valence                                0.634
# year                                    1920
# duration_min                         2.80555
# Name: 0, dtype: object

# %% [markdown]
# Newest and loudest song:

# %%
df.sort_values(by=['year','tempo'], ascending=[False,False]).iloc[0]
# Out:
# acousticness                            0.0489
# artists             [J Balvin,  Jeon,  Anitta]
# danceability                             0.642
# duration_ms                             189653
# energy                                   0.837
# explicit                                     0
# id                      0caF41CcNMjpG6AoV6xHB9
# instrumentalness                             0
# key                                          4
# liveness                                0.0898
# loudness                                -3.356
# mode                                         1
# name                                   Machika
# popularity                                   0
# release_date                        2021-01-22
# speechiness                              0.367
# tempo                                  211.968
# valence                                  0.523
# year                                      2021
# duration_min                           3.16088
# Name: 19865, dtype: object

# %% [markdown]
# ### What makes a song popular?

# %% [markdown]
# Let's aggregate by popularity, to see these relationships more clearly:

# %%
mean_by_popularity = df.groupby(by='popularity').mean().reset_index()
mean_by_popularity
# Out:
#     popularity  acousticness  danceability    duration_ms    energy  explicit  \
# 0            0      0.686870      0.532300  231501.194593  0.362382  0.079765
# 1            1      0.664209      0.515032  232236.778967  0.385811  0.029703
# 2            2      0.632248      0.512122  231608.636993  0.423087  0.023063
# 3            3      0.631016      0.511365  211356.902778  0.444724  0.011218
# 4            4      0.650044      0.502556  208418.051916  0.418885  0.006799
# ..         ...           ...           ...            ...       ...       ...
# 93          93      0.718000      0.675500  164633.000000  0.461000  0.500000
# 94          94      0.177660      0.789600  167209.400000  0.510800  0.600000
# 95          95      0.306500      0.797000  192018.500000  0.619500  1.000000
# 96          96      0.344500      0.718500  156425.500000  0.762000  1.000000
# 97         100      0.721000      0.585000  242014.000000  0.436000  1.000000
#
#     instrumentalness        key  liveness   loudness      mode  speechiness  \
# 0       3.415497e-01   5.224194  0.220316 -14.030980  0.674268     0.195604
# 1       2.922477e-01   5.428686  0.225508 -13.750756  0.683168     0.161253
# 2       2.913310e-01   5.190959  0.234347 -12.754102  0.695111     0.122784
# 3       3.199950e-01   5.142628  0.239475 -12.294946  0.697115     0.086457
# 4       3.412457e-01   5.313350  0.238968 -12.631209  0.697157     0.095630
# ..               ...        ...       ...        ...       ...          ...
# 93      7.950000e-07   7.000000  0.111800  -8.939500  1.000000     0.203750
# 94      2.600000e-02   4.200000  0.134720  -6.823800  0.600000     0.132320
# 95      2.726000e-04   2.500000  0.108000  -7.108500  0.000000     0.103200
# 96      0.000000e+00   3.500000  0.182550  -4.164500  0.500000     0.062350
# 97      1.310000e-05  10.000000  0.105000  -8.761000  1.000000     0.060100
#
#          tempo   valence         year  duration_min
# 0   112.122256  0.498639  1959.237257      3.858353
# 1   114.508610  0.463973  1962.585764      3.870613
# 2   115.547566  0.477612  1967.328875      3.860144
# 3   116.805191  0.499185  1971.490385      3.522615
# 4   116.796001  0.484398  1971.213226      3.473634
# ..         ...       ...          ...           ...
# 93  104.047000  0.311450  2020.000000      2.743883
# 94  103.832000  0.559200  2020.000000      2.786823
# 95  136.918000  0.491500  2020.000000      3.200308
# 96  117.502000  0.719000  2020.000000      2.607092
# 97  143.874000  0.132000  2021.000000      4.033567
#
# [98 rows x 16 columns]

# %% [markdown]
# And now let's see the relationships between popularity and the other variables

# %%
@interact
def time_plot(x=list(mean_by_popularity.drop(['duration_ms'], axis=1).columns)[1:]):
   
    mean_by_popularity.iplot(kind='scatter', x=x, y='popularity', mode='markers', size=5,
             xTitle=x.title(), yTitle='popularity', theme='white', colors='#1DB954',
             title=f'Popularity vs mean {x.title()}')
# Out:
# interactive(children=(Dropdown(description='x', options=('acousticness', 'danceability', 'energy', 'explicit',…

# %% [markdown]
# - It turns out that **most recent songs are more popular**. This is caused somehow by the way the popularity is calculated: it takes into account the total number of plays and **how recent** those plays are. This can add a bias on the relationship of popularity and other features of the songs.
#
#
# - A summary is that the popular songs are the ones:
#     - more danceable,
#     - with more audio engineering,
#     - louder,
#     - and not very long (3.5 min)

# %% [markdown]
# ### Examples of most and less popular songs

# %% [markdown]
# Which are the **less popular** songs?

# %%
df[df['popularity']== 0]
# Out:
#         acousticness                          artists  danceability  \
# 7            0.99600  [Mamie Smith & Her Jazz Hounds]         0.474
# 8            0.99600               [Francisco Canaro]         0.469
# 9            0.00682                         [Meetya]         0.571
# 10           0.95200                       [Dorville]         0.688
# 11           0.99600               [Francisco Canaro]         0.579
# ...              ...                              ...           ...
# 172224       0.79500                   [Alessia Cara]         0.429
# 172225       0.79500                   [Alessia Cara]         0.429
# 172226       0.79500                   [Alessia Cara]         0.429
# 172227       0.79500                   [Alessia Cara]         0.429
# 172228       0.79500                   [Alessia Cara]         0.429
#
#         duration_ms  energy  explicit                      id  \
# 7            186173   0.239         0  02FzJbHtqElixxCmrpSCUa
# 8            146840   0.238         0  02i59gYdjlhBmbbWhf8YuK
# 9            476304   0.753         0  06NUxS2XL3efRh0bloxkHm
# 10           150067   0.220         0  07jrRR1CUUoPb1FLfSy9Jh
# 11           167213   0.356         0  0ANuF7SvPeIHanGcCpy9jR
# ...             ...     ...       ...                     ...
# 172224       144720   0.211         0  3N3Wi5Un7iT8amLezSRwub
# 172225       144720   0.211         0  45XnLMuqf3vRfskEAMUeCH
# 172226       144720   0.211         0  4pPFI9jsguIh3wC7Otoyy8
# 172227       144720   0.211         0  52YtxLVUyvtiGPxwwxayHZ
# 172228       144720   0.211         0  7tue2Wemjd0FZzRtDrQFZd
#
#         instrumentalness  key  liveness  loudness  mode  \
# 7                  0.186    9     0.195    -9.712     1
# 8                  0.960    8     0.149   -18.717     1
# 9                  0.873    8     0.092    -6.943     1
# 10                 0.000    6     0.262   -15.208     0
# 11                 0.948   10     0.174   -14.574     1
# ...                  ...  ...       ...       ...   ...
# 172224             0.000    4     0.196   -11.665     1
# 172225             0.000    4     0.196   -11.665     1
# 172226             0.000    4     0.196   -11.665     1
# 172227             0.000    4     0.196   -11.665     1
# 172228             0.000    4     0.196   -11.665     1
#
#                                 name  popularity release_date  speechiness  \
# 7                     Arkansas Blues           0         1920       0.0289
# 8       La Chacarera - Remasterizado           0   1920-07-08       0.0741
# 9       Broken Puppet - Original Mix           0   1920-01-01       0.0446
# 10                             Oouin           0         1920       0.8450
# 11         Desengaño - Remasterizado           0   1920-07-08       0.0394
# ...                              ...         ...          ...          ...
# 172224                 A Little More           0   2021-01-22       0.0360
# 172225                 A Little More           0   2021-01-22       0.0360
# 172226                 A Little More           0   2021-01-22       0.0360
# 172227                 A Little More           0   2021-01-22       0.0360
# 172228                 A Little More           0   2021-01-22       0.0360
#
#           tempo  valence  year  duration_min
# 7        78.784    0.366  1920      3.102883
# 8       130.060    0.621  1920      2.447333
# 9       126.993    0.119  1920      7.938400
# 10       82.024    0.414  1920      2.501117
# 11      131.494    0.703  1920      2.786883
# ...         ...      ...   ...           ...
# 172224   94.710    0.228  2021      2.412000
# 172225   94.710    0.228  2021      2.412000
# 172226   94.710    0.228  2021      2.412000
# 172227   94.710    0.228  2021      2.412000
# 172228   94.710    0.228  2021      2.412000
#
# [39729 rows x 20 columns]

# %% [markdown]
# There are a lot of songs with popularity zero! Let's take the less danceable and loud:

# %%
df[df['popularity']==0].sort_values(by=['danceability', 'loudness']).head(13)
# Out:
#         acousticness                                            artists  \
# 22610          0.000                                    [Benny Goodman]
# 22679          0.000                                    [Benny Goodman]
# 61738          0.000                                    [Future Rapper]
# 61830          0.000                                    [Sarah Vaughan]
# 142980         0.000                                    [Sarah Vaughan]
# 144203         0.978                                      [Unspecified]
# 156496         0.137                                   [N.A.T.E. Jones]
# 159136         0.729  [Wolfgang Amadeus Mozart,  Sebastian Fischer, ...
# 95426          0.974                                       [Ogden Nash]
# 92718          0.227                                          [Corey-G]
# 23247          0.493                                   [Mathias Wieman]
# 155759         0.650                                      [Miles Davis]
# 758            0.996                                  [Ignacio Corsini]
#
#         danceability  duration_ms  energy  explicit                      id  \
# 22610            0.0         5991  0.0000         0  3IcXTeq9O2dpsSXsDj9naH
# 22679            0.0         6362  0.0000         0  523qs4UcGlQ6ycdha1VGqs
# 61738            0.0       420000  0.0000         0  0Rd7eiAZGayLT8TmrVpQzG
# 61830            0.0         5108  0.0000         0  0hr9kRUi2X4MXc72A4VxG4
# 142980           0.0         6467  0.0000         0  3lRVIn6D6EUbvkOgPZAU1H
# 144203           0.0        42107  0.1890         0  07kyGuUKm3yIFs8AoLExJj
# 156496           0.0         8042  0.2790         1  334gn6CIPuCzq5laDm1m0Y
# 159136           0.0        11493  0.1460         0  0CpFb3YFhEo2EgDOSQaGbe
# 95426            0.0         9680  0.1160         0  0R5mcFkjcryBDgw9vKpFSo
# 92718            0.0        12000  0.1010         1  1N4jTBZnj2M3SOTLB8FXPs
# 23247            0.0       129722  0.0134         0  24mFr4NTDNpYYUtlsfy4Y1
# 155759           0.0         9053  0.1280         0  2QlykwFFdgDg4xU7oftghh
# 758              0.0       133947  0.0258         0  2WTtJDfCUjAyCZHRSfCLDn
#
#         instrumentalness  key  liveness  loudness  mode  \
# 22610           0.000000    0    0.0000   -60.000     0
# 22679           0.000000    0    0.0000   -60.000     0
# 61738           0.000000    0    0.0000   -60.000     0
# 61830           0.000000    0    0.0000   -60.000     0
# 142980          0.000000    0    0.0000   -60.000     0
# 144203          0.920000   10    0.1140   -36.524     1
# 156496          0.000122   10    0.3420   -29.832     0
# 159136          0.000000    7    0.4020   -27.851     1
# 95426           0.045700    5    0.2050   -27.357     1
# 92718           0.000000    5    0.2640   -26.782     0
# 23247           0.000000    8    0.5040   -26.028     1
# 155759          0.000000    0    0.4420   -25.523     1
# 758             0.768000    5    0.0831   -24.894     1
#
#                                                      name  popularity  \
# 22610                                  Pause Track - Live           0
# 22679                                  Pause Track - Live           0
# 61738                 StaggerLee Has His Day at the Beach           0
# 61830                                         Pause Track           0
# 142980                                        Pause Track           0
# 144203  Stethoscope Sounds: Normal Heart and Lung Soun...           0
# 156496                   Happy New Years!! (Clear Vision)           0
# 159136  Die Zauberflöte, K.620 / Act 1: Ist's denn Wir...           0
# 95426                                 The Perfect Husband           0
# 92718                                 Happy New Year 2019           0
# 23247                                     Das Vermächtnis           0
# 155759  Introduction to Miles Ahead Medley - Live at M...           0
# 758                      La Mina del Ford - Remasterizado           0
#
#        release_date  speechiness  tempo  valence  year  duration_min
# 22610          1938          0.0    0.0      0.0  1938      0.099850
# 22679          1938          0.0    0.0      0.0  1938      0.106033
# 61738    1949-02-17          0.0    0.0      0.0  1949      7.000000
# 61830          1949          0.0    0.0      0.0  1949      0.085133
# 142980         1949          0.0    0.0      0.0  1949      0.107783
# 144203   1955-01-01          0.0    0.0      0.0  1955      0.701783
# 156496   2020-01-01          0.0    0.0      0.0  2020      0.134033
# 159136   1955-01-01          0.0    0.0      0.0  1955      0.191550
# 95426    1950-01-01          0.0    0.0      0.0  1950      0.161333
# 92718    2019-01-01          0.0    0.0      0.0  2019      0.200000
# 23247    1941-11-01          0.0    0.0      0.0  1941      2.162033
# 155759   2002-08-20          0.0    0.0      0.0  2002      0.150883
# 758      1924-03-29          0.0    0.0      0.0  1924      2.232450

# %% [markdown]
# The first 12 tracks are pause tracks, or speech introductions... there is even a track with just silence for 7 minutes!!
#
# The first one that is really a song is a tango, *La mina del Ford*, from the singer *Ignacio Corsini*

# %% [markdown]
# Let's see the **most popular** songs:

# %%
df[df['popularity']> 95].sort_values(by='popularity', ascending=False)
# Out:
#        acousticness                 artists  danceability  duration_ms  \
# 19768         0.721        [Olivia Rodrigo]         0.585       242014
# 19588         0.221  [24kGoldn,  iann dior]         0.700       140526
# 19591         0.468         [Ariana Grande]         0.737       172325
#
#        energy  explicit                      id  instrumentalness  key  \
# 19768   0.436         1  7lPN2DXiMsVn7XUKtOW1CS          0.000013   10
# 19588   0.722         1  3tjFYV6RSFtuktYl3ZtYcq          0.000000    7
# 19591   0.802         1  35mvY5S1H3J2QZyna3TFe0          0.000000    0
#
#        liveness  loudness  mode                    name  popularity  \
# 19768    0.1050    -8.761     1         drivers license         100
# 19588    0.2720    -3.558     0  Mood (feat. iann dior)          96
# 19591    0.0931    -4.771     1               positions          96
#
#       release_date  speechiness    tempo  valence  year  duration_min
# 19768   2021-01-08       0.0601  143.874    0.132  2021      4.033567
# 19588   2020-07-24       0.0369   90.989    0.756  2020      2.342100
# 19591   2020-10-30       0.0878  144.015    0.682  2020      2.872083

# %% [markdown]
# All of these are famous artists: Olivia Rodrigo is a former Disney Channel actress, 24kgoldn is a rapper with other succesful themes and Ariana Grande is, well, Ariana Grande

# %% [markdown]
# ### Does the key of a songs affects to other features?

# %%
mean_by_key = df.groupby(by='key').mean().reset_index()
mean_by_key['duration_min'] = mean_by_year['duration_ms']/(1000*60)
mean_by_key['key'] = mean_by_key['key'].map(
    {0:'C', 1:'C#', 2:'D', 3:'D#', 4:'E', 5:'F', 6:'F#', 7:'G', 8:'G#', 9:'A', 10:'A#', 11:'B'})
mean_by_key
# Out:
#    key  acousticness  danceability    duration_ms    energy  explicit  \
# 0    C      0.518295      0.532754  232269.551497  0.460860  0.057347
# 1   C#      0.439267      0.564078  231804.163926  0.498519  0.139034
# 2    D      0.487484      0.521206  236255.269840  0.495301  0.053015
# 3   D#      0.685961      0.496564  226733.973283  0.384241  0.029900
# 4    E      0.475399      0.523851  235468.511801  0.505455  0.055962
# 5    F      0.582946      0.529292  231789.071398  0.437731  0.042961
# 6   F#      0.437523      0.561007  227724.400463  0.512985  0.110670
# 7    G      0.497629      0.534822  232274.135130  0.481861  0.058779
# 8   G#      0.550528      0.533388  230736.403868  0.461607  0.069302
# 9    A      0.446203      0.535586  230870.395578  0.520386  0.047803
# 10  A#      0.565001      0.542349  233715.104209  0.446032  0.062525
# 11   B      0.393541      0.565775  238862.161594  0.540293  0.125069
#
#     instrumentalness  liveness   loudness      mode  popularity  speechiness  \
# 0           0.191891  0.213467 -11.979978  0.808521   26.039199     0.095243
# 1           0.192247  0.208647 -11.887598  0.755569   25.789356     0.176447
# 2           0.190954  0.213842 -11.540599  0.778837   26.978526     0.084144
# 3           0.244568  0.198109 -13.000934  0.776024   21.109911     0.086853
# 4           0.185151  0.220298 -11.407504  0.559692   27.624182     0.082983
# 5           0.206887  0.210515 -12.287754  0.656252   24.555379     0.090210
# 6           0.188979  0.214424 -11.499361  0.579034   26.370040     0.157110
# 7           0.195315  0.217148 -11.745701  0.801118   26.122721     0.089693
# 8           0.207500  0.197323 -11.869540  0.810959   25.168942     0.098754
# 9           0.175271  0.205842 -11.230454  0.659446   27.461629     0.095671
# 10          0.205562  0.203382 -12.197575  0.640072   24.022063     0.109617
# 11          0.184821  0.224014 -11.141110  0.444844   26.885630     0.150079
#
#          tempo   valence         year  duration_min
# 0   117.188636  0.526403  1975.701244      3.968217
# 1   115.967498  0.505154  1978.435865      4.298196
# 2   117.897979  0.523099  1977.392203      2.335586
# 3   114.867187  0.497562  1967.682447      2.965706
# 4   117.845289  0.513354  1979.111771      3.184112
# 5   115.222857  0.530210  1972.781717      3.079627
# 6   115.936454  0.521821  1979.628638      2.630606
# 7   117.394189  0.533041  1977.108748      2.942380
# 8   115.884323  0.518518  1974.814941      3.573267
# 9   119.419618  0.543805  1978.606437      2.813260
# 10  114.773095  0.527864  1974.001791      3.244852
# 11  118.187744  0.537504  1981.003228      2.859404

# %%
@interact
def key_plot(y=list(mean_by_key.drop(['duration_ms', 'key'], axis=1).columns)):
  
    mean_by_key.iplot(kind='scatter', x='key', y=y, mode='lines+markers', size=5,
             xTitle='key', yTitle=y.title(), theme='white', colors='#1DB954',
             title=f'{y.title()} mean for every key')
# Out:
# interactive(children=(Dropdown(description='y', options=('acousticness', 'danceability', 'energy', 'explicit',…

# %% [markdown]
# - The songs in **D#** are not very popular! These are songs like *Rolling in the Deep* (*Adele*) and *Bohemian Rhapsody* (*Queen*)
